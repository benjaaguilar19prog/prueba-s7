# %% [markdown]
# <a href="https://colab.research.google.com/github/benjaaguilar19prog/prueba-s7/blob/main/prueba_s7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# Notebook almacenado s-7

# %%
import seaborn as sns
